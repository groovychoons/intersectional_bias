# %%
import pandas as pd
import configparser
import openai

# Load configuration file
config = configparser.ConfigParser()
config.read('../config.ini')

openai.api_key = config.get('API', 'OPENAI_API_KEY')

# %%
filename = '../data/to_fix.csv'

# Read the TSV file into a pandas DataFrame
df = pd.read_csv(filename, on_bad_lines='warn')

# %%
df
# Out:
#             auid                     name EthnicSeer      prop  \
# 0      9731334_2      Cameron 'Dale' Bass        ITA  0.653567
# 1      2155715_1                Bert Hart        ENG  0.772359
# 2      7867892_1                Leen Hart        ENG  0.980865
# 3     14609221_2       Esther Nolte- Hoen        GER  0.665081
# 4      8101337_1            Ellen 't Hoen        CHI  0.665526
# ...          ...                      ...        ...       ...
# 1997   5539805_1             Alison Moore        ENG  0.973204
# 1998   2591432_4     Gerasimos Alivizatos        RUS  0.625319
# 1999  16921340_2       Tufik Alizade Sani        ARA  0.961992
# 2000  17914518_3        Azin Alizadeh Asl        ARA  0.947498
# 2001  12428068_1  Mahvash Alizadeh-Naeeni        ARA  0.999988
#
#              lastname  firstname   Ethnea Genni       SexMac SSNgender  \
# 0         'Dale' Bass    Cameron  ENGLISH     M  mostly_male         -
# 1                Hart       Bert    DUTCH     M         male         M
# 2                Hart       Leen    DUTCH     -         male         F
# 3         Nolte- Hoen     Esther   GERMAN     F       female         F
# 4             't Hoen      Ellen    DUTCH     F       female         F
# ...               ...        ...      ...   ...          ...       ...
# 1997            Moore     Alison  ENGLISH     F       female         F
# 1998       Alivizatos  Gerasimos    GREEK     M         male         M
# 1999     Alizade Sani      Tufik     ARAB     M         andy         -
# 2000     Alizadeh Asl       Azin     ARAB     F       female         -
# 2001  Alizadeh-Naeeni    Mahvash     ARAB     F       female         -
#
#      Highest_probF_ethnicity  Highest_probF_value
# 0                    ENGLISH               92.191
# 1                      DUTCH               87.200
# 2                      DUTCH               98.679
# 3                   HISPANIC               43.243
# 4                      DUTCH               37.459
# ...                      ...                  ...
# 1997                 ENGLISH               98.446
# 1998                   GREEK               98.341
# 1999                    ARAB               77.443
# 2000                    ARAB               99.801
# 2001                    ARAB               93.938
#
# [2002 rows x 12 columns]

# %%
names = df['firstname'].head(1000).tolist()
print(names[:10])
# Out:
# ['Cameron', 'Bert', 'Leen', 'Esther', 'Ellen', 'Peter', 'Geert', 'Andrea', 'Max', 'Carolyn']

# %%
# List to store embeddings
embeddings = []

# Retrieve embeddings for each name
for name in names:
    response = openai.Embedding.create(
        input=name,
        model="text-embedding-ada-002"
    )
    embedding = response['data'][0]['embedding']
    embeddings.append(embedding)

# %%
# Select the first 200 rows using iloc
subset_df = df.head(1000).copy()

# Create a new column 'Embedding' and assign the embeddings
subset_df['Embedding'] = embeddings[:1000]

# Print the updated DataFrame
print(subset_df)

# Export DataFrame to CSV file
subset_df.to_csv('../data/embeddings.csv', index=False)
# Out:
#            auid                   name EthnicSeer      prop      lastname  \
# 0     9731334_2    Cameron 'Dale' Bass        ITA  0.653567   'Dale' Bass
# 1     2155715_1              Bert Hart        ENG  0.772359          Hart
# 2     7867892_1              Leen Hart        ENG  0.980865          Hart
# 3    14609221_2     Esther Nolte- Hoen        GER  0.665081   Nolte- Hoen
# 4     8101337_1          Ellen 't Hoen        CHI  0.665526       't Hoen
# ..          ...                    ...        ...       ...           ...
# 995   8296003_1     Luigi Lazzari Agli        ITA  0.999036  Lazzari Agli
# 996  10750176_2         Marlene Aglony        GER  0.397017        Aglony
# 997  15564501_6  Habibatou Diallo-Agne        FRN  0.998308   Diallo-Agne
# 998     69097_2      Giancarlo Agnelli        ITA  0.999509       Agnelli
# 999  15853199_2              Agnes Ban        ENG  0.461761           Ban
#
#      firstname           Ethnea Genni       SexMac SSNgender  \
# 0      Cameron          ENGLISH     M  mostly_male         -
# 1         Bert            DUTCH     M         male         M
# 2         Leen            DUTCH     -         male         F
# 3       Esther           GERMAN     F       female         F
# 4        Ellen            DUTCH     F       female         F
# ..         ...              ...   ...          ...       ...
# 995      Luigi          ITALIAN     M         male         M
# 996    Marlene         HISPANIC     F       female         F
# 997  Habibatou          AFRICAN     F         andy         F
# 998  Giancarlo          ITALIAN     M         male         M
# 999      Agnes  JAPANESE-FRENCH     F       female         F
#
#     Highest_probF_ethnicity  Highest_probF_value  \
# 0                   ENGLISH               92.191
# 1                     DUTCH               87.200
# 2                     DUTCH               98.679
# 3                  HISPANIC               43.243
# 4                     DUTCH               37.459
# ..                      ...                  ...
# 995                 ITALIAN               97.564
# 996                HISPANIC               36.237
# 997                 AFRICAN               76.961
# 998                 ITALIAN               99.122
# 999                  FRENCH               64.738
#
#                                              Embedding
# 0    [0.0027535639237612486, -0.006899471394717693,...
# 1    [-0.012196633964776993, -0.034759119153022766,...
# 2    [0.00720670260488987, -0.011822231113910675, 0...
# 3    [-0.02559061162173748, -0.02379501983523369, -...
# 4    [-0.014605682343244553, -0.030205124989151955,...
# ..                                                 ...
# 995  [0.004992321133613586, -0.012878835201263428, ...
# 996  [-0.03219403699040413, -0.00232181278988719, 0...
# 997  [-0.01831855997443199, 0.003941226284950972, -...
# 998  [-0.008049694821238518, 0.009363795630633831, ...
# 999  [0.0027832789346575737, -0.018790127709507942,...
#
# [1000 rows x 13 columns]
