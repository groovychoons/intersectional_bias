# %%
import pandas as pd
import configparser
import openai

# Load configuration file
config = configparser.ConfigParser()
config.read('../config.ini')

openai.api_key = config.get('API', 'OPENAI_API_KEY')

# %%
filename = '../data/first_names_0-4000.csv'

# Read the TSV file into a pandas DataFrame
df = pd.read_csv(filename, on_bad_lines='warn')

# %%
df
# Out:
#             auid                         name EthnicSeer      prop  \
# 0      9731334_2          Cameron 'Dale' Bass        ITA  0.653567
# 1      2155715_1                    Bert Hart        ENG  0.772359
# 2      7867892_1                    Leen Hart        ENG  0.980865
# 3     14609221_2           Esther Nolte- Hoen        GER  0.665081
# 4      8101337_1                Ellen 't Hoen        CHI  0.665526
# ...          ...                          ...        ...       ...
# 4141  13079875_2                Tamas Banyasz        ENG  0.548975
# 4142  12316049_1                   Banza Baya        SPA  0.312835
# 4143  16360893_1  Nadja Erika Banziger-Tobler        GER  0.988877
# 4144   8645296_1                Qing Bao Tian        CHI  0.999304
# 4145   8809361_2                    Bao An Ma        CHI  0.975016
#
#                    lastname firstname     Ethnea Genni       SexMac SSNgender  \
# 0               'Dale' Bass   Cameron    ENGLISH     M  mostly_male         -
# 1                      Hart      Bert      DUTCH     M         male         M
# 2                      Hart      Leen      DUTCH     -         male         F
# 3               Nolte- Hoen    Esther     GERMAN     F       female         F
# 4                   't Hoen     Ellen      DUTCH     F       female         F
# ...                     ...       ...        ...   ...          ...       ...
# 4141                Banyasz     Tamas  HUNGARIAN     M         male         M
# 4142                   Baya     Banza   HISPANIC     -         andy         -
# 4143  Erika Banziger-Tobler     Nadja     GERMAN     F       female         F
# 4144               Bao Tian      Qing    CHINESE     -         andy         F
# 4145                  An Ma       Bao    CHINESE     -  mostly_male         -
#
#      Highest_probF_ethnicity  Highest_probF_value
# 0                    ENGLISH               92.191
# 1                      DUTCH               87.200
# 2                      DUTCH               98.679
# 3                   HISPANIC               43.243
# 4                      DUTCH               37.459
# ...                      ...                  ...
# 4141               HUNGARIAN               93.765
# 4142                HISPANIC               88.393
# 4143                  GERMAN               86.357
# 4144                 CHINESE               93.511
# 4145                 CHINESE               98.356
#
# [4146 rows x 12 columns]

# %%
names = df['firstname'].head(4000).tolist()
print(names[:10])
# Out:
# ['Cameron', 'Bert', 'Leen', 'Esther', 'Ellen', 'Peter', 'Geert', 'Andrea', 'Max', 'Carolyn']

# %%
# List to store embeddings
embeddings = []

# Retrieve embeddings for each name
for name in names:
    response = openai.Embedding.create(
        input=name,
        model="text-embedding-ada-002"
    )
    embedding = response['data'][0]['embedding']
    embeddings.append(embedding)

# %%
# Select the first 200 rows using iloc
subset_df = df.head(4000).copy()

# Create a new column 'Embedding' and assign the embeddings
subset_df['Embedding'] = embeddings[:4000]

# Print the updated DataFrame
print(subset_df)

# Export DataFrame to CSV file
subset_df.to_csv('../data/embeddings.csv', index=False)
# Out:
#             auid                      name EthnicSeer      prop      lastname  \
# 0      9731334_2       Cameron 'Dale' Bass        ITA  0.653567   'Dale' Bass
# 1      2155715_1                 Bert Hart        ENG  0.772359          Hart
# 2      7867892_1                 Leen Hart        ENG  0.980865          Hart
# 3     14609221_2        Esther Nolte- Hoen        GER  0.665081   Nolte- Hoen
# 4      8101337_1             Ellen 't Hoen        CHI  0.665526       't Hoen
# ...          ...                       ...        ...       ...           ...
# 3995  10974234_3   Veeramuthu Balakrishnan        IND  1.000000  Balakrishnan
# 3996   5532244_1      Vallath Balakrishnan        IND  0.997178  Balakrishnan
# 3997  11506617_2    Rengarajan Balamurugan        IND  0.996938   Balamurugan
# 3998  10426449_1  Balamurugan Sampathkumar        IND  0.999982  Sampathkumar
# 3999   8422397_3             Chenera Balan        RUS  0.444481         Balan
#
#         firstname    Ethnea Genni       SexMac SSNgender  \
# 0         Cameron   ENGLISH     M  mostly_male         -
# 1            Bert     DUTCH     M         male         M
# 2            Leen     DUTCH     -         male         F
# 3          Esther    GERMAN     F       female         F
# 4           Ellen     DUTCH     F       female         F
# ...           ...       ...   ...          ...       ...
# 3995   Veeramuthu    INDIAN     -         andy         -
# 3996      Vallath    INDIAN     -         andy         -
# 3997   Rengarajan    INDIAN     M         andy         -
# 3998  Balamurugan    INDIAN     M         andy         -
# 3999      Chenera  ROMANIAN     -         andy         -
#
#      Highest_probF_ethnicity  Highest_probF_value  \
# 0                    ENGLISH               92.191
# 1                      DUTCH               87.200
# 2                      DUTCH               98.679
# 3                   HISPANIC               43.243
# 4                      DUTCH               37.459
# ...                      ...                  ...
# 3995                  INDIAN               97.739
# 3996                  INDIAN               73.630
# 3997                  INDIAN               74.383
# 3998                  INDIAN               79.123
# 3999                    SLAV               64.296
#
#                                               Embedding
# 0     [0.002752959029749036, -0.006888952571898699, ...
# 1     [-0.012196633964776993, -0.034759119153022766,...
# 2     [0.00720670260488987, -0.011822231113910675, 0...
# 3     [-0.02559061162173748, -0.02379501983523369, -...
# 4     [-0.014605682343244553, -0.030205124989151955,...
# ...                                                 ...
# 3995  [-0.026633543893694878, -0.02088879607617855, ...
# 3996  [-0.011875685304403305, -0.009170440025627613,...
# 3997  [0.0070220064371824265, 0.0025403141044080257,...
# 3998  [-0.01752883940935135, -0.017201565206050873, ...
# 3999  [0.0011020292295143008, 0.009018750861287117, ...
#
# [4000 rows x 13 columns]
