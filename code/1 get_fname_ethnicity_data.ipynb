# %%
import pandas as pd
import os

# %%
filename = '../data/genni-ethnea-authority2009.tsv'

# Read the TSV file into a pandas DataFrame
df = pd.read_csv(filename, delimiter='\t', on_bad_lines='warn')
# Out:
# b'Skipping line 1864435: expected 10 fields, saw 13\n'

# %%
df
# Out:
#                auid                 name EthnicSeer      prop  \
# 0         9731334_2  Cameron 'Dale' Bass        ITA  0.653567
# 1         2155715_1            Bert Hart        ENG  0.772359
# 2         7867892_1            Leen Hart        ENG  0.980865
# 3        14609221_2   Esther Nolte- Hoen        GER  0.665081
# 4         8101337_1        Ellen 't Hoen        CHI  0.665526
# ...             ...                  ...        ...       ...
# 2799447    849591_2               Haddad        ARA  0.927991
# 2799448   8683651_5               Haddad        ARA  0.927991
# 2799449   8714244_2         monia Haddad        ARA  0.988955
# 2799450   9289496_7               Haddad        ARA  0.927991
# 2799451  13653457_3     BONARELLI RULLIF        ITA  0.748362
#
#                  lastname firstname       Ethnea Genni       SexMac SSNgender
# 0             'Dale' Bass   Cameron      ENGLISH     M  mostly_male         -
# 1                    Hart      Bert        DUTCH     M         male         M
# 2                    Hart      Leen        DUTCH     -         male         F
# 3             Nolte- Hoen    Esther       GERMAN     F       female         F
# 4                 't Hoen     Ellen        DUTCH     F       female         F
# ...                   ...       ...          ...   ...          ...       ...
# 2799447            Haddad         X  ARAB-FRENCH     -         andy         -
# 2799448            Haddad         X  ARAB-FRENCH     -         andy         -
# 2799449            Haddad     monia         ARAB     F       female         F
# 2799450            Haddad         X  ARAB-FRENCH     -         andy         -
# 2799451  BONARELLI RULLIF         X      ITALIAN     -         andy         -
#
# [2799452 rows x 10 columns]

# %%
# Assuming you have a DataFrame named 'df' with a column named 'firstname'

# Capitalize all first names
df['firstname'] = df['firstname'].str.capitalize()

# Remove names with spaces or hyphens or len 1 or less
df = df[df['firstname'].str.len() > 1]
df = df[~df['firstname'].str.contains(r'[\s-]')]

# Create a new DataFrame with unique names
unique_names_df = df.drop_duplicates(subset='firstname', keep='first', ignore_index=True)

# Print the DataFrame with unique names and data
print(unique_names_df.head())
# Out:
#          auid                 name EthnicSeer      prop     lastname  \
# 0   9731334_2  Cameron 'Dale' Bass        ITA  0.653567  'Dale' Bass
# 1   2155715_1            Bert Hart        ENG  0.772359         Hart
# 2   7867892_1            Leen Hart        ENG  0.980865         Hart
# 3  14609221_2   Esther Nolte- Hoen        GER  0.665081  Nolte- Hoen
# 4   8101337_1        Ellen 't Hoen        CHI  0.665526      't Hoen
#
#   firstname   Ethnea Genni       SexMac SSNgender
# 0   Cameron  ENGLISH     M  mostly_male         -
# 1      Bert    DUTCH     M         male         M
# 2      Leen    DUTCH     -         male         F
# 3    Esther   GERMAN     F       female         F
# 4     Ellen    DUTCH     F       female         F

# %%
ethnea_counts = unique_names_df['Ethnea'].value_counts()
print(ethnea_counts.to_string())
# Out:
# CHINESE                 15047
# HISPANIC                11597
# INDIAN                  10171
# ENGLISH                  7529
# ARAB                     6250
# JAPANESE                 5507
# THAI                     3240
# KOREAN                   3101
# SLAV                     2737
# NORDIC                   2410
# GERMAN                   2059
# TURKISH                  2007
# FRENCH                   1916
# DUTCH                    1840
# AFRICAN                  1825
# ITALIAN                  1669
# ISRAELI                  1024
# GREEK                    1012
# UNKNOWN                   506
# ENGLISH-HISPANIC          472
# ENGLISH-INDIAN            304
# BALTIC                    271
# INDIAN-ARAB               246
# INDIAN-ENGLISH            242
# ARAB-INDIAN               220
# ENGLISH-CHINESE           214
# ENGLISH-FRENCH            209
# ENGLISH-ARAB              197
# HUNGARIAN                 195
# HISPANIC-ENGLISH          191
# ROMANIAN                  179
# GERMAN-ENGLISH            178
# ENGLISH-NORDIC            176
# FRENCH-ENGLISH            169
# ENGLISH-GERMAN            160
# HISPANIC-ITALIAN          147
# ITALIAN-HISPANIC          142
# GERMAN-HISPANIC           141
# FRENCH-HISPANIC           135
# ENGLISH-SLAV              123
# HISPANIC-FRENCH           121
# FRENCH-ARAB               114
# ARAB-CHINESE              113
# ARAB-HISPANIC             112
# INDONESIAN                110
# ENGLISH-ITALIAN           110
# HISPANIC-ARAB             110
# ARAB-FRENCH               106
# CHINESE-ENGLISH           100
# VIETNAMESE                 99
# ARAB-ENGLISH               99
# SLAV-HISPANIC              98
# INDIAN-CHINESE             93
# INDIAN-HISPANIC            93
# NORDIC-ENGLISH             93
# ENGLISH-TURKISH            90
# ENGLISH-AFRICAN            88
# GERMAN-NORDIC              85
# HISPANIC-INDIAN            83
# HISPANIC-GERMAN            81
# CHINESE-HISPANIC           80
# JAPANESE-CHINESE           79
# ENGLISH-DUTCH              79
# HISPANIC-SLAV              78
# SLAV-ARAB                  77
# ITALIAN-ENGLISH            75
# DUTCH-ENGLISH              74
# HISPANIC-NORDIC            73
# GERMAN-FRENCH              73
# CHINESE-KOREAN             72
# ENGLISH-JAPANESE           71
# ENGLISH-KOREAN             70
# KOREAN-CHINESE             69
# ENGLISH-ISRAELI            69
# ARAB-TURKISH               69
# FRENCH-GERMAN              68
# AFRICAN-ENGLISH            68
# JAPANESE-HISPANIC          67
# AFRICAN-HISPANIC           67
# AFRICAN-ARAB               64
# ENGLISH-THAI               63
# INDIAN-SLAV                62
# ARAB-SLAV                  62
# CHINESE-INDIAN             61
# INDIAN-NORDIC              60
# AFRICAN-JAPANESE           59
# INDIAN-THAI                59
# INDIAN-TURKISH             58
# HISPANIC-JAPANESE          58
# GERMAN-DUTCH               57
# SLAV-ENGLISH               56
# AFRICAN-INDIAN             56
# INDIAN-JAPANESE            56
# CHINESE-ARAB               56
# AFRICAN-CHINESE            54
# CHINESE-JAPANESE           51
# NORDIC-GERMAN              51
# ENGLISH-GREEK              51
# SLAV-INDIAN                50
# HISPANIC-CHINESE           50
# HISPANIC-TURKISH           49
# ITALIAN-INDIAN             48
# GERMAN-ARAB                47
# JAPANESE-INDIAN            46
# DUTCH-FRENCH               45
# NORDIC-INDIAN              45
# AFRICAN-FRENCH             45
# GERMAN-INDIAN              44
# ISRAELI-ENGLISH            44
# GERMAN-SLAV                44
# NORDIC-HISPANIC            43
# FRENCH-DUTCH               43
# TURKISH-ARAB               42
# FRENCH-INDIAN              42
# DUTCH-GERMAN               42
# GERMAN-CHINESE             42
# JAPANESE-ARAB              41
# THAI-INDIAN                41
# ARAB-NORDIC                41
# HISPANIC-DUTCH             40
# ITALIAN-ARAB               40
# FRENCH-CHINESE             38
# DUTCH-HISPANIC             38
# CHINESE-NORDIC             37
# HISPANIC-AFRICAN           37
# SLAV-NORDIC                37
# ISRAELI-ARAB               36
# ISRAELI-HISPANIC           35
# ARAB-GERMAN                35
# ARAB-AFRICAN               35
# FRENCH-TURKISH             35
# NORDIC-ARAB                34
# FRENCH-AFRICAN             34
# INDIAN-FRENCH              33
# SLAV-GERMAN                33
# FRENCH-ITALIAN             33
# CHINESE-THAI               32
# SLAV-TURKISH               32
# KOREAN-ENGLISH             32
# AFRICAN-NORDIC             31
# JAPANESE-AFRICAN           31
# CHINESE-GERMAN             31
# JAPANESE-NORDIC            30
# JAPANESE-KOREAN            30
# ARAB-ISRAELI               30
# INDIAN-AFRICAN             30
# GERMAN-ITALIAN             30
# ITALIAN-FRENCH             30
# SLAV-FRENCH                30
# CHINESE-FRENCH             30
# INDIAN-ISRAELI             30
# JAPANESE-ENGLISH           30
# ITALIAN-SLAV               29
# ARAB-JAPANESE              29
# INDIAN-ITALIAN             29
# THAI-CHINESE               29
# HISPANIC-ISRAELI           28
# SLAV-CHINESE               28
# HISPANIC-GREEK             28
# FRENCH-NORDIC              28
# CHINESE-TURKISH            26
# TURKISH-HISPANIC           26
# NORDIC-FRENCH              26
# SLAV-ISRAELI               26
# GERMAN-TURKISH             26
# INDIAN-KOREAN              26
# ARAB-THAI                  26
# GERMAN-ISRAELI             25
# THAI-ENGLISH               24
# TURKISH-INDIAN             24
# INDIAN-GERMAN              24
# ITALIAN-NORDIC             23
# DUTCH-NORDIC               23
# CHINESE-AFRICAN            23
# DUTCH-SLAV                 23
# KOREAN-JAPANESE            23
# FRENCH-SLAV                22
# KOREAN-HISPANIC            22
# NORDIC-CHINESE             22
# SLAV-JAPANESE              22
# HISPANIC-THAI              22
# ITALIAN-CHINESE            22
# NORDIC-SLAV                21
# CHINESE-SLAV               21
# MONGOLIAN                  21
# HISPANIC-KOREAN            21
# THAI-SLAV                  20
# AFRICAN-SLAV               20
# THAI-JAPANESE              20
# INDIAN-DUTCH               20
# TURKISH-SLAV               20
# NORDIC-TURKISH             20
# THAI-HISPANIC              20
# GERMAN-GREEK               20
# KOREAN-INDIAN              19
# GREEK-ENGLISH              19
# AFRICAN-TURKISH            19
# FRENCH-ISRAELI             19
# ENGLISH-BALTIC             19
# GERMAN-THAI                19
# ISRAELI-CHINESE            18
# THAI-ARAB                  18
# TURKISH-CHINESE            18
# NORDIC-DUTCH               18
# ARAB-ITALIAN               18
# ISRAELI-GERMAN             18
# AFRICAN-GERMAN             18
# GREEK-HISPANIC             18
# ARAB-DUTCH                 17
# JAPANESE-SLAV              17
# FRENCH-GREEK               17
# AFRICAN-ISRAELI            17
# DUTCH-INDIAN               17
# SLAV-GREEK                 17
# ITALIAN-GERMAN             17
# JAPANESE-THAI              17
# SLAV-ITALIAN               17
# DUTCH-ARAB                 17
# FRENCH-JAPANESE            17
# NORDIC-JAPANESE            17
# CHINESE-ISRAELI            16
# FRENCH-THAI                16
# AFRICAN-ITALIAN            16
# JAPANESE-FRENCH            16
# VIETNAMESE-FRENCH          16
# JAPANESE-TURKISH           16
# CARIBBEAN                  16
# AFRICAN-DUTCH              16
# ISRAELI-TURKISH            16
# GERMAN-AFRICAN             16
# NORDIC-AFRICAN             15
# SLAV-AFRICAN               15
# ENGLISH-HUNGARIAN          15
# GERMAN-KOREAN              15
# SLAV-THAI                  15
# ITALIAN-TURKISH            15
# ARAB-KOREAN                15
# NORDIC-ISRAELI             15
# JAPANESE-ITALIAN           15
# GERMAN-JAPANESE            15
# ITALIAN-GREEK              14
# DUTCH-CHINESE              14
# ISRAELI-FRENCH             14
# ITALIAN-JAPANESE           14
# CHINESE-DUTCH              14
# ENGLISH-ROMANIAN           13
# THAI-FRENCH                13
# ISRAELI-INDIAN             13
# KOREAN-THAI                13
# GREEK-FRENCH               13
# ARAB-GREEK                 13
# SLAV-DUTCH                 13
# TURKISH-ENGLISH            13
# TURKISH-KOREAN             13
# ISRAELI-SLAV               13
# ITALIAN-DUTCH              12
# SLAV-KOREAN                12
# ISRAELI-THAI               12
# THAI-KOREAN                12
# HUNGARIAN-HISPANIC         11
# VIETNAMESE-ENGLISH         11
# HISPANIC-BALTIC            11
# KOREAN-TURKISH             11
# JAPANESE-GERMAN            11
# DUTCH-ITALIAN              11
# ITALIAN-ROMANIAN           10
# GREEK-INDIAN               10
# TURKISH-NORDIC             10
# DUTCH-THAI                 10
# FRENCH-KOREAN              10
# DUTCH-ISRAELI              10
# GREEK-CHINESE              10
# NORDIC-BALTIC              10
# GREEK-ARAB                 10
# AFRICAN-THAI               10
# DUTCH-JAPANESE             10
# TURKISH-JAPANESE           10
# INDIAN-HUNGARIAN           10
# NORDIC-ITALIAN             10
# FRENCH-HUNGARIAN            9
# KOREAN-NORDIC               9
# CHINESE-ITALIAN             9
# HUNGARIAN-CHINESE           9
# ISRAELI-NORDIC              9
# DUTCH-AFRICAN               9
# HUNGARIAN-ENGLISH           9
# THAI-ISRAELI                9
# ROMANIAN-FRENCH             9
# ITALIAN-AFRICAN             9
# DUTCH-TURKISH               9
# NORDIC-KOREAN               9
# FRENCH-VIETNAMESE           8
# ROMANIAN-SLAV               8
# ISRAELI-AFRICAN             8
# CHINESE-VIETNAMESE          8
# THAI-TURKISH                8
# KOREAN-FRENCH               8
# NORDIC-GREEK                8
# TURKISH-GERMAN              8
# SLAV-HUNGARIAN              7
# GREEK-SLAV                  7
# INDONESIAN-CHINESE          7
# ROMANIAN-HISPANIC           7
# ITALIAN-THAI                7
# JAPANESE-INDONESIAN         7
# THAI-GERMAN                 7
# VIETNAMESE-KOREAN           7
# AFRICAN-KOREAN              7
# TURKISH-FRENCH              7
# ITALIAN-KOREAN              7
# GREEK-GERMAN                7
# GERMAN-HUNGARIAN            7
# CHINESE-INDONESIAN          7
# JAPANESE-GREEK              7
# THAI-DUTCH                  7
# KOREAN-DUTCH                7
# JAPANESE-DUTCH              7
# BALTIC-HISPANIC             7
# DUTCH-KOREAN                7
# SLAV-BALTIC                 7
# ISRAELI-ITALIAN             7
# ARAB-INDONESIAN             7
# INDIAN-GREEK                7
# THAI-NORDIC                 6
# THAI-ITALIAN                6
# NORDIC-THAI                 6
# INDIAN-ROMANIAN             6
# ITALIAN-ISRAELI             6
# TURKISH-ISRAELI             6
# GREEK-NORDIC                6
# GREEK-JAPANESE              6
# KOREAN-ARAB                 6
# VIETNAMESE-CHINESE          6
# TURKISH-THAI                6
# JAPANESE-ROMANIAN           6
# DUTCH-GREEK                 6
# INDONESIAN-HISPANIC         6
# ENGLISH-VIETNAMESE          6
# ENGLISH-CARIBBEAN           6
# MONGOLIAN-JAPANESE          6
# TURKISH-GREEK               6
# CHINESE-BALTIC              5
# AFRICAN-HUNGARIAN           5
# ROMANIAN-ITALIAN            5
# CARIBBEAN-ENGLISH           5
# HUNGARIAN-NORDIC            5
# INDONESIAN-JAPANESE         5
# BALTIC-GERMAN               5
# SLAV-ROMANIAN               5
# INDONESIAN-INDIAN           5
# INDONESIAN-ARAB             5
# HUNGARIAN-INDIAN            5
# ARAB-HUNGARIAN              5
# KOREAN-GREEK                5
# GREEK-ITALIAN               5
# AFRICAN-GREEK               5
# TURKISH-AFRICAN             5
# ISRAELI-DUTCH               5
# GREEK-TURKISH               5
# GREEK-AFRICAN               5
# INDIAN-INDONESIAN           5
# KOREAN-GERMAN               5
# HISPANIC-ROMANIAN           5
# HUNGARIAN-GERMAN            5
# ISRAELI-GREEK               4
# DUTCH-INDONESIAN            4
# ITALIAN-HUNGARIAN           4
# BALTIC-GREEK                4
# HUNGARIAN-FRENCH            4
# FRENCH-ROMANIAN             4
# ISRAELI-JAPANESE            4
# HUNGARIAN-AFRICAN           4
# JAPANESE-ISRAELI            4
# KOREAN-VIETNAMESE           4
# THAI-AFRICAN                4
# CHINESE-GREEK               4
# GERMAN-ROMANIAN             4
# ENGLISH-INDONESIAN          4
# ISRAELI-KOREAN              4
# HISPANIC-HUNGARIAN          4
# ROMANIAN-GREEK              4
# BALTIC-NORDIC               3
# ITALIAN-BALTIC              3
# KOREAN-HUNGARIAN            3
# KOREAN-SLAV                 3
# KOREAN-ITALIAN              3
# HUNGARIAN-ROMANIAN          3
# MONGOLIAN-ARAB              3
# HISPANIC-INDONESIAN         3
# GREEK-DUTCH                 3
# GERMAN-BALTIC               3
# THAI-HUNGARIAN              3
# BALTIC-SLAV                 3
# GERMAN-VIETNAMESE           3
# GREEK-BALTIC                3
# TURKISH-ITALIAN             3
# KOREAN-ISRAELI              3
# AFRICAN-ROMANIAN            3
# TURKISH-ROMANIAN            3
# HUNGARIAN-ARAB              3
# ROMANIAN-AFRICAN            3
# ITALIAN-INDONESIAN          3
# POLYNESIAN                  3
# ROMANIAN-DUTCH              3
# INDONESIAN-GERMAN           3
# ARAB-BALTIC                 3
# GREEK-ISRAELI               2
# ARAB-MONGOLIAN              2
# TURKISH-MONGOLIAN           2
# TURKISH-DUTCH               2
# CARIBBEAN-GERMAN            2
# POLYNESIAN-JAPANESE         2
# HUNGARIAN-ITALIAN           2
# ROMANIAN-NORDIC             2
# THAI-GREEK                  2
# GERMAN-MONGOLIAN            2
# ROMANIAN-TURKISH            2
# ROMANIAN-HUNGARIAN          2
# HUNGARIAN-GREEK             2
# VIETNAMESE-NORDIC           2
# INDONESIAN-NORDIC           2
# BALTIC-DUTCH                2
# CHINESE-ROMANIAN            2
# INDONESIAN-DUTCH            2
# INDIAN-BALTIC               2
# GREEK-HUNGARIAN             2
# ROMANIAN-INDIAN             2
# HUNGARIAN-BALTIC            2
# ARAB-CARIBBEAN              2
# HUNGARIAN-SLAV              2
# INDONESIAN-ITALIAN          2
# NORDIC-ROMANIAN             2
# CARIBBEAN-AFRICAN           2
# CHINESE-HUNGARIAN           2
# INDONESIAN-AFRICAN          2
# FRENCH-BALTIC               2
# KOREAN-AFRICAN              2
# BALTIC-CHINESE              1
# INDIAN-VIETNAMESE           1
# NORDIC-VIETNAMESE           1
# GREEK-INDONESIAN            1
# AFRICAN-BALTIC              1
# JAPANESE-BALTIC             1
# ROMANIAN-ARAB               1
# MONGOLIAN-SLAV              1
# POLYNESIAN-HISPANIC         1
# JAPANESE-HUNGARIAN          1
# INDONESIAN-TURKISH          1
# DUTCH-HUNGARIAN             1
# VIETNAMESE-ROMANIAN         1
# HUNGARIAN-JAPANESE          1
# FRENCH-MONGOLIAN            1
# ROMANIAN-THAI               1
# HUNGARIAN-ISRAELI           1
# HISPANIC-MONGOLIAN          1
# ISRAELI-ROMANIAN            1
# GREEK-ROMANIAN              1
# VIETNAMESE-HISPANIC         1
# ENGLISH-MONGOLIAN           1
# INDONESIAN-ENGLISH          1
# THAI-INDONESIAN             1
# BALTIC-ENGLISH              1
# MONGOLIAN-ITALIAN           1
# JAPANESE-MONGOLIAN          1
# VIETNAMESE-INDIAN           1
# TURKISH-VIETNAMESE          1
# ROMANIAN-GERMAN             1
# DUTCH-VIETNAMESE            1
# TURKISH-INDONESIAN          1
# NORDIC-POLYNESIAN           1
# KOREAN-INDONESIAN           1
# TURKISH-CARIBBEAN           1
# AFRICAN-CARIBBEAN           1
# HUNGARIAN-KOREAN            1
# INDONESIAN-SLAV             1
# HUNGARIAN-INDONESIAN        1
# CARIBBEAN-INDIAN            1
# MONGOLIAN-INDIAN            1
# INDONESIAN-ISRAELI          1
# CHINESE-CARIBBEAN           1
# NORDIC-HUNGARIAN            1
# FRENCH-CARIBBEAN            1
# GREEK-KOREAN                1
# VIETNAMESE-DUTCH            1
# ROMANIAN-ENGLISH            1
# GERMAN-CARIBBEAN            1
# MONGOLIAN-TURKISH           1
# DUTCH-BALTIC                1
# FRENCH-INDONESIAN           1
# CARIBBEAN-SLAV              1
# INDIAN-CARIBBEAN            1
# GERMAN-INDONESIAN           1
# TOOSHORT-ERROR              1
# DUTCH-ROMANIAN              1
# SLAV-MONGOLIAN              1
# CARIBBEAN-HISPANIC          1
# ARAB-ROMANIAN               1
# CARIBBEAN-CHINESE           1
# BALTIC-INDIAN               1
# TURKISH-HUNGARIAN           1
# NORDIC-INDONESIAN           1
# BALTIC-ISRAELI              1

# %%
unique_names_df['Genni'].value_counts()
# Out:
# -    59452
# M    17954
# F    17912
# Name: Genni, dtype: int64

# %%
import requests
from bs4 import BeautifulSoup
import time

def scrape_ethnicity_table(first_name, last_name):
    url = f"http://abel.lis.illinois.edu/cgi-bin/ethnea/search.py?Fname={first_name}&Lname={last_name}"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    table = soup.find('table')

    # Extract the table rows
    rows = table.find_all('tr')

    # Extract the table headers
    # headers = [header.text for header in rows[0].find_all('th')]

    # Extract the table data
    data = [[cell.text for cell in row.find_all('td')] for row in rows[1:]]

    # Find the ethnicity with the highest probF
    max_probF_ethnicity = None
    max_probF_value = 0.0
    for row in data:
        ethnicity = row[0]
        probF = float(row[4])
        if probF > max_probF_value:
            max_probF_ethnicity = ethnicity
            max_probF_value = probF

    # Update the DataFrame with the highest probF ethnicity and probF value
    unique_names_df.loc[(unique_names_df['firstname'] == first_name) & (unique_names_df['lastname'] == last_name), 'Highest_probF_ethnicity'] = max_probF_ethnicity
    unique_names_df.loc[(unique_names_df['firstname'] == first_name) & (unique_names_df['lastname'] == last_name), 'Highest_probF_value'] = max_probF_value

chunk_size = 1000

# Iterate over the DataFrame in chunks
for i in range(0, len(unique_names_df), chunk_size):
    chunk_df = unique_names_df.iloc[i:i+chunk_size]  # Get the current chunk of rows

    # Perform the scraping for each row in the chunk
    for index, row in chunk_df.iterrows():
        first_name = row['firstname']
        last_name = row['lastname']
        scrape_ethnicity_table(first_name, last_name)
        time.sleep(1)  # Delay for 1 second before the next request
    
    # Generate a unique filename for each chunk
    filename = f"../data/first_names_{i//chunk_size}.csv"

    # Save the chunk DataFrame to a CSV file
    unique_names_df.iloc[i:i+chunk_size].to_csv(filename, index=False)

# %%
import os
import pandas as pd

# Step 1: Define the folder path where the CSV files are located
folder_path = '../data/'

# Step 2: Get a list of all CSV files in the folder
csv_files = [file for file in os.listdir(folder_path) if file.startswith('first_names_') and file.endswith('.csv')]

# Step 3: Merge all CSV files into a single DataFrame
df_list = []
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    df_list.append(df)

merged_df = pd.concat(df_list, ignore_index=True)
merged_df.drop_duplicates(inplace=True)

# Step 4: Save the merged DataFrame to a new CSV file
merged_csv_path = '../data/first_names_raw_data.csv'
merged_df.to_csv(merged_csv_path, index=False)

print("Merged CSV file has been created successfully!")
# Out:
# Merged CSV file has been created successfully!
